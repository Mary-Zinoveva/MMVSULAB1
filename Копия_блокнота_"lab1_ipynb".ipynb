# %% [markdown]
# <a href="https://colab.research.google.com/github/Mary-Zinoveva/MMVSULAB1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22lab1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа №1

# %% [markdown]
# Построение математической модели x'=kx

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

#Определяем функцию, задающую значения параметрам дифференциального уравнения, определяем вид диффура
def dydt(y,t):
  k=0.012
  return k*y

#Создаем область построения
t=np.linspace(0,33,33)

#решаем диффур, обозначаем функцию решения solve
solve=odeint(dydt, y0=9017415, t=t)
solve=solve.flatten()

years=[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]
burn=[9017415,9067808,9066025,9066612,9085457,9246727,9411236,9604297,9783242,9932932,10114203,10382754,10386903,10535681,10726429,10923762,11091428,11186851,11281631,11503501,11776764,11856578,11979529,12108257,12197596,12330126,12380664,12506468,12615279,12678079,13010112,13015126,13097539]
#Строим график мат.модели
# %matplotlib inline
plt.plot(years, solve, label=r"$x'=kx$")
plt.plot(years, burn, color="green")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Построение математической модели x'=k(x)x, где k(x)=ax-b

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

#Определяем функцию, задающую значения параметрам дифференциального уравнения, определяем вид диффура
def dydt(y,t):
  a=0
  b=-0.012
  return (a*y-b)*y

#Создаем область построения
t=np.linspace(0,33,33)

#решаем диффур, обозначаем функцию решения solve
solve=odeint(dydt, y0=9017415, t=t)
solve=solve.flatten()
years=[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]
burn=[9017415,9067808,9066025,9066612,9085457,9246727,9411236,9604297,9783242,9932932,10114203,10382754,10386903,10535681,10726429,10923762,11091428,11186851,11281631,11503501,11776764,11856578,11979529,12108257,12197596,12330126,12380664,12506468,12615279,12678079,13010112,13015126,13097539]
#Строим график мат.модели
# %matplotlib inline
plt.plot(years, solve, label=r"$x'=k(x)x$")
plt.plot(years, burn, color="green")

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Построение математической модели x'=k(x)x-c

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

#Определяем функцию, задающую значения параметрам дифференциального уравнения, определяем вид диффура
def dydt(y,t):
  a=0
  b=-0.012
  c=20000
  return (a*y-b)*y-c
#Создаем область построения
t=np.linspace(0,33,33)
#решаем диффур, обозначаем функцию решения solve
solve=odeint(dydt, y0=9017415, t=t)
solve=solve.flatten()
burn=[9017415,9067808,9066025,9066612,9085457,9246727,9411236,9604297,9783242,9932932,10114203,10382754,10386903,10535681,10726429,10923762,11091428,11186851,11281631,11503501,11776764,11856578,11979529,12108257,12197596,12330126,12380664,12506468,12615279,12678079,13010112,13015126,13097539	]

#Строим график мат.модели
# %matplotlib inline
plt.plot(t, solve, label=r"$x'=k(x)x-c$")
plt.plot(t, burn, color="green")

plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Построение математической модели x'=k(x)x-c(x)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
#Определяем функцию, задающую значения параметрам дифференциального уравнения, определяем вид диффура
def dydt(y,t):
  a=1
  b=1
  c1=1
  c2=1
  return (a*y-b)*y-(c1*y-c2)
#Создаем область построения
t=np.linspace(0,10,100)
#решаем диффур, обозначаем функцию решения solve
solve=odeint(dydt, y0=1, t=t)
solve=solve.flatten()
#Строим график мат.модели
# %matplotlib inline
plt.plot(t, solve, label=r"$x'=k(x)x-c(x)$")
plt.grid(True)
plt.legend()
plt.show()
